# %%
import os,re
import docx2txt
import textract
import pandas as pd
import numpy as np
from docx import Document
import nltk
import matplotlib.pyplot as plt
# from wordcloud import WordCloud
from sklearn.naive_bayes import MultinomialNB
from sklearn.multiclass import OneVsRestClassifier
from sklearn import metrics
from sklearn.metrics import accuracy_score,precision_score
from pandas.plotting import scatter_matrix
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
nltk.download("stopwords")
# import xgboost as xgb
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\vijay\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import os,re
import textract
import docx
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 7
#       4 import seaborn as sns
#       6 import os,re
# ----> 7 import textract
#       8 import docx
#
# ModuleNotFoundError: No module named 'textract'

# %%
file_path = []
category = []
directory = 'Resumes'

for i in os.listdir(directory):
  if i.endswith('.docx') or i.endswith('.doc') or i.endswith('.pdf'):
    os.path.join(directory, i)
    file_path.append((textract.process(os.path.join(directory, i))).decode('utf-8'))
    category.append('React JS Developer Resume')

# %%
import os
from PyPDF2 import PdfReader

file_paths = []
category = []
directory = 'Resumes'

for filename in os.listdir(directory):
    if filename.endswith('.docx') or filename.endswith('.doc') or filename.endswith('.pdf'):
        file_path = os.path.join(directory, filename)
        if filename.endswith('.pdf'):
            with open(file_path, 'rb') as pdf_file:
                reader = PdfReader(pdf_file)
                text = ''
                for page in reader.pages:
                    text += page.extract_text()  # Extract text from each page
        elif filename.endswith('.docx'):
            # Handling DOCX files
            from docx import Document
            doc = Document(file_path)
            text = ''
            for paragraph in doc.paragraphs:
                text += paragraph.text
        else:
            # Handle .doc files using a different method/library
            # For example, you can use antiword or textract
            # Make sure to install the necessary libraries
            # and implement the appropriate extraction method here
            text = extract_text_from_doc(file_path)
        file_paths.append(text.encode('utf-8'))
        category.append('React JS Developer Resume')
# Out:
# Error: PyMuPDF doesn't natively handle DOC/DOCX files.. Text extraction from DOC/DOCX is not supported by PyMuPDF.
# Error: PyMuPDF doesn't natively handle DOC/DOCX files.. Text extraction from DOC/DOCX is not supported by PyMuPDF.
# Error: PyMuPDF doesn't natively handle DOC/DOCX files.. Text extraction from DOC/DOCX is not supported by PyMuPDF.

# %%
file_paths
# Out:
# [b'Name: Ravali P                                                                              Curriculum Vitae                                           Specialization: BE (computer science and Engg)    To utilize my technical skills for achieving the target and developing the best performance in organization.     \t  MANUAL TESTING SKILLS     Strong knowledge in SDLC concepts.    Extensive knowledge in White Box Testing.    Good knowledge in Functional testing, Integration testing,    Extreme Knowledge on System Testing    Good knowledge in Adhoc Testing, Reliability testing.    Good Knowledge on Exploratory Testing    Good knowledge in STLC concepts.    Good knowledge in Test cases and Test scenarios.    Good knowledge in globalization testing, compatibility testing.    Through Knowledge on Regression Testing    Good  knowledge in Test plan.         AGILE METHDOLOGY     Good knowledge on Scrum Methodology.    Expertise in Sprint Planning Meeting.    Good knowledge on Scrum Meeting
# ...

# %%
import os
from PyPDF2 import PdfReader

file_paths = []
category = []
directory = 'Resumes'

for filename in os.listdir(directory):
    if filename.endswith('.docx') or filename.endswith('.doc') or filename.endswith('.pdf'):
        file_path = os.path.join(directory, filename)
        if filename.endswith('.pdf'):
            with open(file_path, 'rb') as pdf_file:
                reader = PdfReader(pdf_file)
                text = ''
                for page in reader.pages:
                    text += page.extract_text()  # Extract text from each page
        elif filename.endswith('.docx'):
            # Handling DOCX files
            from docx import Document
            doc = Document(file_path)
            text = ''
            for paragraph in doc.paragraphs:
                text += paragraph.text
        else:
            if filename.endswith('.doc'):
                
                # Handling DOC files
                import docx2txt
                text = docx2txt.process(file_path)
                # Handle .doc files using a different method/library
                # For example, you can use antiword or textract
                # Make sure to install the necessary libraries
                # and implement the appropriate extraction method here
            text = extract_text_from_doc(file_path)
        file_paths.append(text.encode('utf-8'))
        category.append('React JS Developer Resume')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 29
#      25 if filename.endswith('.doc'):
#      26
#      27     # Handling DOC files
#      28     import docx2txt
# ---> 29     text = docx2txt.process(file_path)
#      30     # Handle .doc files using a different method/library
#      31     # For example, you can use antiword or textract
#      32     # Make sure to install the necessary libraries
#      33     # and implement the appropriate extraction method here
#      34 text = extract_text_from_doc(file_path)
#
# File ~\anaconda3\Lib\site-packages\docx2txt\docx2txt.py:88, in process(docx, img_dir)
#      86 # get main text
#      87 doc_xml = 'word/document.xml'
# ---> 88 text += xml2text(zipf.read(doc_xml))
#      90 # get footer text
#      91 # there can be 3 footer files in the zip
#      92 footer_xmls = 'word/footer[0-9]*.xml'
#
# ...
